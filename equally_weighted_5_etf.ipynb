# %% [markdown]
# <a href="https://colab.research.google.com/github/Hades2323/finance-alpha/blob/main/equally_weighted_5_etf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Equally weighted con 5 ETF

# %%
import pandas as pd
import numpy as np
import copy
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Scarichiamo gli indici

# %%
urlo = "https://raw.githubusercontent.com/paolocole/Stock-Indexes-Historical-Data/main/DAILY/NET/EUR/"

elenco = pd.read_excel("https://www.paolocoletti.com/wp-content/uploads/youtube/etfs_with_msci.xlsx" , sheet_name="selezionati" , index_col=0)
elenco["url"] = urlo + elenco["Path"] + "/" + elenco["File"] + ".csv"
elenco["url"] = elenco["url"].str.replace("\\","/")
elenco
# Out:
#                                                                        Path  \
# MSCI index
# WORLD                     DEVELOPED-MARKETS-DM\Region\NONE\NONE\STANDARD...
# EMERGING MARKETS IMI      EMERGING-MARKETS-EM\Region\NONE\NONE\IMI-LARGE...
# ACWI                      ALL-COUNTRY-DM-EM\Region\NONE\NONE\STANDARD-LA...
# EUROPE                    DEVELOPED-MARKETS-DM\Region\NONE\NONE\STANDARD...
# USA                       DEVELOPED-MARKETS-DM\Country\NONE\NONE\STANDAR...
# EMERGING MARKETS          EMERGING-MARKETS-EM\Region\NONE\NONE\STANDARD-...
# JAPAN IMI                 DEVELOPED-MARKETS-DM\Country\NONE\NONE\IMI-LAR...
# INDIA                     EMERGING-MARKETS-EM\Country\NONE\NONE\STANDARD...
# WORLD SMALL CAP             DEVELOPED-MARKETS-DM\Region\NONE\NONE\SMALL-CAP
# EMU                       DEVELOPED-MARKETS-DM\Region\NONE\NONE\STANDARD...
# JAPAN                     DEVELOPED-MARKETS-DM\Country\NONE\NONE\STANDAR...
# CHINA                     EMERGING-MARKETS-EM\Country\NONE\NONE\STANDARD...
# EM ASIA                   EMERGING-MARKETS-EM\Region\NONE\NONE\STANDARD-...
# PACIFIC EX JAPAN          DEVELOPED-MARKETS-DM\Region\NONE\NONE\STANDARD...
# BRAZIL                    EMERGING-MARKETS-EM\Country\NONE\NONE\STANDARD...
# EUROPE SMALL CAP            DEVELOPED-MARKETS-DM\Region\NONE\NONE\SMALL-CAP
# CHINA A                   EMERGING-MARKETS-EM\Country\NONE\NONE\STANDARD...
# EM EX-CHINA               EMERGING-MARKETS-EM\Region\NONE\NONE\STANDARD-...
# UK                        DEVELOPED-MARKETS-DM\Country\NONE\NONE\STANDAR...
# WORLD EX USA              DEVELOPED-MARKETS-DM\Region\NONE\NONE\STANDARD...
# EUROPE EX-UK              DEVELOPED-MARKETS-DM\Region\NONE\NONE\STANDARD...
# NORDIC                    DEVELOPED-MARKETS-DM\Region\NONE\NONE\STANDARD...
# CANADA                    DEVELOPED-MARKETS-DM\Country\NONE\NONE\STANDAR...
# NORTH AMERICA             DEVELOPED-MARKETS-DM\Region\NONE\NONE\STANDARD...
# EMU SMALL CAP               DEVELOPED-MARKETS-DM\Region\NONE\NONE\SMALL-CAP
# AC FAR EAST EX-JAPAN      ALL-COUNTRY-DM-EM\Region\NONE\NONE\STANDARD-LA...
# WORLD EX EMU              DEVELOPED-MARKETS-DM\Region\NONE\NONE\STANDARD...
# WORLD EX EUROPE           DEVELOPED-MARKETS-DM\Region\NONE\NONE\STANDARD...
# TAIWAN                    EMERGING-MARKETS-EM\Country\NONE\NONE\STANDARD...
# SAUDI ARABIA CAPPED       EMERGING-MARKETS-EM\Country\NONE\NONE\STANDARD...
# EM LATIN AMERICA          EMERGING-MARKETS-EM\Region\NONE\NONE\STANDARD-...
# MEXICO                    EMERGING-MARKETS-EM\Country\NONE\NONE\STANDARD...
# AUSTRALIA                 DEVELOPED-MARKETS-DM\Country\NONE\NONE\STANDAR...
# JAPAN SMALL CAP            DEVELOPED-MARKETS-DM\Country\NONE\NONE\SMALL-CAP
# SWITZERLAND               DEVELOPED-MARKETS-DM\Country\NONE\NONE\STANDAR...
# AC ASIA EX JAPAN          ALL-COUNTRY-DM-EM\Region\NONE\NONE\STANDARD-LA...
# EASTERN EUROPE EX RUSSIA  EMERGING-MARKETS-EM\Region\NONE\NONE\STANDARD-...
# KOREA                     EMERGING-MARKETS-EM\Country\NONE\NONE\STANDARD...
# UK SMALL CAP               DEVELOPED-MARKETS-DM\Country\NONE\NONE\SMALL-CAP
# SINGAPORE                 DEVELOPED-MARKETS-DM\Country\NONE\NONE\STANDAR...
# SOUTH AFRICA              EMERGING-MARKETS-EM\Country\NONE\NONE\STANDARD...
# FRANCE                    DEVELOPED-MARKETS-DM\Country\NONE\NONE\STANDAR...
# POLAND                    EMERGING-MARKETS-EM\Country\NONE\NONE\STANDARD...
# GREECE                    EMERGING-MARKETS-EM\Country\NONE\NONE\STANDARD...
# INDONESIA                 EMERGING-MARKETS-EM\Country\NONE\NONE\STANDARD...
# WORLD EX USA              https://raw.githubusercontent.com/paolocole/St...
# EUROPE EX-UK              https://raw.githubusercontent.com/paolocole/St...
# NORDIC                    https://raw.githubusercontent.com/paolocole/St...
# CANADA                    https://raw.githubusercontent.com/paolocole/St...
# NORTH AMERICA             https://raw.githubusercontent.com/paolocole/St...
# EMU SMALL CAP             https://raw.githubusercontent.com/paolocole/St...
# AC FAR EAST EX-JAPAN      https://raw.githubusercontent.com/paolocole/St...
# WORLD EX EMU              https://raw.githubusercontent.com/paolocole/St...
# WORLD EX EUROPE           https://raw.githubusercontent.com/paolocole/St...
# TAIWAN                    https://raw.githubusercontent.com/paolocole/St...
# SAUDI ARABIA CAPPED       https://raw.githubusercontent.com/paolocole/St...
# EM LATIN AMERICA          https://raw.githubusercontent.com/paolocole/St...
# MEXICO                    https://raw.githubusercontent.com/paolocole/St...
# AUSTRALIA                 https://raw.githubusercontent.com/paolocole/St...
# JAPAN SMALL CAP           https://raw.githubusercontent.com/paolocole/St...
# SWITZERLAND               https://raw.githubusercontent.com/paolocole/St...
# AC ASIA EX JAPAN          https://raw.githubusercontent.com/paolocole/St...
# EASTERN EUROPE EX RUSSIA  https://raw.githubusercontent.com/paolocole/St...
# KOREA                     https://raw.githubusercontent.com/paolocole/St...
# UK SMALL CAP              https://raw.githubusercontent.com/paolocole/St...
# SINGAPORE                 https://raw.githubusercontent.com/paolocole/St...
# SOUTH AFRICA              https://raw.githubusercontent.com/paolocole/St...
# FRANCE                    https://raw.githubusercontent.com/paolocole/St...
# POLAND                    https://raw.githubusercontent.com/paolocole/St...
# GREECE                    https://raw.githubusercontent.com/paolocole/St...
# INDONESIA                 https://raw.githubusercontent.com/paolocole/St...
# TURKEY                    https://raw.githubusercontent.com/paolocole/St...

# %%
dati = pd.DataFrame()
for nome in elenco.index:
    print(nome, end=" - ")
    df = pd.read_csv(elenco.loc[nome,"url"], index_col=0)
    df.index = pd.to_datetime(df.index)
#    df.dropna(inplace=True)
    dati = pd.concat([dati,df], axis=1)
dati = dati.resample('ME',label="right").last().to_period("M")
# Out:
# WORLD - EMERGING MARKETS IMI - ACWI - EUROPE - USA - EMERGING MARKETS - JAPAN IMI - INDIA - WORLD SMALL CAP - EMU - JAPAN - CHINA - EM ASIA - PACIFIC EX JAPAN - BRAZIL - EUROPE SMALL CAP - CHINA A - EM EX-CHINA - UK - WORLD EX USA - EUROPE EX-UK - NORDIC - CANADA - NORTH AMERICA - EMU SMALL CAP - AC FAR EAST EX-JAPAN - WORLD EX EMU - WORLD EX EUROPE - TAIWAN - SAUDI ARABIA CAPPED - EM LATIN AMERICA - MEXICO - AUSTRALIA - JAPAN SMALL CAP - SWITZERLAND - AC ASIA EX JAPAN - EASTERN EUROPE EX RUSSIA - KOREA - UK SMALL CAP - SINGAPORE - SOUTH AFRICA - FRANCE - POLAND - GREECE - INDONESIA - TURKEY -

# %%
dati
# Out:
#               WORLD  EM (EMERGING MARKETS) IMI        ACWI      EUROPE  \
# Date
# 1998-12         NaN                 306.018626         NaN         NaN
# 1999-01         NaN                 300.452653         NaN         NaN
#
# [312 rows x 46 columns]

# %%
rendimenti = dati.pct_change(fill_method=None)

# %% [markdown]
# ### Funzioni di utilità

# %%
# poco efficiente
def portfolio_yearly_returns(which,months): # non ribilanciato!
    rendimenti = []
    for i in range(len(dati.index)-months):
        validi = len(which) - ( dati[which].iloc[i] * dati[which].iloc[i+months] ).isna().sum()
        if validi > 0:
            quote = (100 / validi) / dati[which].iloc[i]
            montante = (quote * dati[which].iloc[i + months]).sum()
            if montante != np.nan: rendimenti.append( ( montante/100 ) )
    return np.array(rendimenti).mean()**(12/months) -1 , np.array(rendimenti).std(), len(rendimenti)

# %%
def portfolio_yearly_returns(which,months): # non ribilanciato!
    rendimenti = []
    for i in range(len(dati.index)-months):
        if ( dati[which].iloc[i].isna() | dati[which].iloc[i+months].isna() ).sum() < len(which):
            rendimenti.append( ( dati[which].iloc[i + months] / dati[which].iloc[i] ).mean() )
    return np.array(rendimenti).mean()**(12/months) -1 , np.array(rendimenti).std(), len(rendimenti)

# %%
# ancora più ottimizzato!
def portfolio_yearly_returns(which,months): # non ribilanciato!
    rendimenti = ( dati[which] / dati[which].shift(months) ).mean(axis=1)
    return ( rendimenti.mean(axis=0)**(12/months) -1 ) , rendimenti.std(axis=0), rendimenti.count().sum()

# %%
portfolio_yearly_returns(["POLAND","GREECE","TURKEY","CHINA A","BRAZIL"],12)  # (0.08327308316346159, 0.277029684889988, 276)
# Out:
# (np.float64(0.08327308316346138), 0.27702968488998814, np.int64(276))

# %% [markdown]
# ## Semplifichiamo basandoci sulle correlazioni

# %%
plt.figure(figsize=(20,15))
sns.heatmap(round(rendimenti.corr()*100,0), cmap="Reds", linewidths=0.1,annot=True, vmin=0, vmax=100, annot_kws={"size": 7})
# Out:
# <Axes: >

# %%
eliminati2 = ["ACWI","USA","NORTH AMERICA","WORLD ex EMU", "WORLD ex EUROPE", "EM (EMERGING MARKETS)", "EM ASIA",
             "EM (EMERGING MARKETS) ex CHINA", "EM ASIA", "AC FAR EAST ex JAPAN", "AC ASIA ex JAPAN", "EMU", "WORLD ex USA",
             "EUROPE ex UK", "FRANCE", "JAPAN", "EM LATIN AMERICA", "EMU SMALL CAP", "AUSTRALIA", "UNITED KINGDOM SMALL CAP", "POLAND"]

# %%
dati2 = dati.drop(columns=eliminati2)
rendimenti2 = rendimenti.drop(columns=eliminati2)

# %%
plt.figure(figsize=(20,15))
sns.heatmap(round(rendimenti2.corr()*100,0), cmap="Reds", linewidths=0.1,annot=True, vmin=0, vmax=100, annot_kws={"size": 11})
# Out:
# <Axes: >

# %% [markdown]
# ## Faccio tutte le combinazioni

# %%
mesi = 60

# %%
# faccio tutte le combinazioni
from itertools import combinations
c = combinations(dati2.columns,5)

# %%
r = []
i = []
for k in c:
    kk = list(k)
    # print(kk)
    i.append(str(kk))
    r.append(portfolio_yearly_returns(kk,mesi))
    if len(i)%1000==0: print(len(i), end=" ")
results = pd.DataFrame(r,index=i,columns=["return","vol","valid"])
results["Sharpetti"] = results["return"]/results["vol"]
# Out:
# 1000 2000 3000 4000 5000 6000 7000 8000 9000 10000 11000 12000 13000 14000 15000 16000 17000 18000 19000 20000 21000 22000 23000 24000 25000 26000 27000 28000 29000 30000 31000 32000 33000 34000 35000 36000 37000 38000 39000 40000 41000 42000 43000 44000 45000 46000 47000 48000 49000 50000 51000 52000 53000 54000 55000 56000 57000 58000 59000 60000 61000 62000 63000 64000 65000

# %%
results.plot(kind="scatter",y="return",x="vol",figsize=(25,10))
# Out:
# <Axes: xlabel='vol', ylabel='return'>

# %%
results["return"].idxmax(),results["return"].max(),results.loc[results["return"].idxmax(),"vol"]
# Out:
# ("['INDIA', 'BRAZIL', 'CHINA A', 'SAUDI ARABIA', 'INDONESIA']",
#  0.14879433973786704,
#  np.float64(1.2251048979042451))

# %%
results.nsmallest(columns="vol",n=10)
# Out:
#                                                       return       vol  valid  \
# ['WORLD', 'CHINA A', 'TAIWAN', 'SAUDI ARABIA', ...  0.086333  0.254857    228
# ['CHINA A', 'TAIWAN', 'SAUDI ARABIA', 'JAPAN SM...  0.082855  0.256306    228
# ['PACIFIC ex JAPAN', 'CHINA A', 'CANADA', 'TAIW...  0.075290  0.259456    252
# ['EUROPE', 'CHINA A', 'TAIWAN', 'JAPAN SMALL CA...  0.076446  0.262768    228
# ['WORLD', 'EUROPE', 'CHINA A', 'TAIWAN', 'SOUTH...  0.079962  0.263408    228
# ['WORLD', 'CHINA A', 'TAIWAN', 'JAPAN SMALL CAP...  0.080602  0.263859    228
# ['EUROPE', 'CHINA A', 'TAIWAN', 'SAUDI ARABIA',...  0.082012  0.264351    228
# ['WORLD', 'PACIFIC ex JAPAN', 'CHINA A', 'TAIWA...  0.081044  0.265038    252
# ['CHINA A', 'CANADA', 'TAIWAN', 'JAPAN SMALL CA...  0.076152  0.265232    252
# ['WORLD', 'PACIFIC ex JAPAN', 'CHINA A', 'CANAD...  0.072153  0.265421    252
#
#                                                     Sharpetti
# ['WORLD', 'CHINA A', 'TAIWAN', 'SAUDI ARABIA', ...   0.338751
# ['CHINA A', 'TAIWAN', 'SAUDI ARABIA', 'JAPAN SM...   0.323264
# ['PACIFIC ex JAPAN', 'CHINA A', 'CANADA', 'TAIW...   0.290183
# ['EUROPE', 'CHINA A', 'TAIWAN', 'JAPAN SMALL CA...   0.290926
# ['WORLD', 'EUROPE', 'CHINA A', 'TAIWAN', 'SOUTH...   0.303565
# ['WORLD', 'CHINA A', 'TAIWAN', 'JAPAN SMALL CAP...   0.305474
# ['EUROPE', 'CHINA A', 'TAIWAN', 'SAUDI ARABIA',...   0.310239
# ['WORLD', 'PACIFIC ex JAPAN', 'CHINA A', 'TAIWA...   0.305784
# ['CHINA A', 'CANADA', 'TAIWAN', 'JAPAN SMALL CA...   0.287113
# ['WORLD', 'PACIFIC ex JAPAN', 'CHINA A', 'CANAD...   0.271842

# %%
results.nlargest(columns="Sharpetti",n=10)
# Out:
#                                                       return       vol  valid  \
# ['WORLD', 'CHINA A', 'TAIWAN', 'SAUDI ARABIA', ...  0.086333  0.254857    228
# ['WORLD', 'TAIWAN', 'SAUDI ARABIA', 'JAPAN SMAL...  0.103639  0.309554    228
# ['WORLD SMALL CAP', 'CHINA A', 'TAIWAN', 'SAUDI...  0.090683  0.273488    228
# ['WORLD', 'CHINA A', 'TAIWAN', 'JAPAN SMALL CAP...  0.099860  0.305633    228
# ['WORLD', 'WORLD SMALL CAP', 'TAIWAN', 'JAPAN S...  0.101306  0.310320    228
# ['WORLD', 'WORLD SMALL CAP', 'CHINA A', 'TAIWAN...  0.105905  0.325931    228
# ['WORLD', 'WORLD SMALL CAP', 'TAIWAN', 'SAUDI A...  0.109917  0.339042    228
# ['CHINA A', 'TAIWAN', 'SAUDI ARABIA', 'JAPAN SM...  0.082855  0.256306    228
# ['WORLD', 'CHINA A', 'TAIWAN', 'SAUDI ARABIA', ...  0.087895  0.277057    228
# ['CHINA A', 'TAIWAN', 'SAUDI ARABIA', 'MEXICO',...  0.084437  0.267377    228
#
#                                                     Sharpetti
# ['WORLD', 'CHINA A', 'TAIWAN', 'SAUDI ARABIA', ...   0.338751
# ['WORLD', 'TAIWAN', 'SAUDI ARABIA', 'JAPAN SMAL...   0.334801
# ['WORLD SMALL CAP', 'CHINA A', 'TAIWAN', 'SAUDI...   0.331580
# ['WORLD', 'CHINA A', 'TAIWAN', 'JAPAN SMALL CAP...   0.326733
# ['WORLD', 'WORLD SMALL CAP', 'TAIWAN', 'JAPAN S...   0.326456
# ['WORLD', 'WORLD SMALL CAP', 'CHINA A', 'TAIWAN...   0.324931
# ['WORLD', 'WORLD SMALL CAP', 'TAIWAN', 'SAUDI A...   0.324200
# ['CHINA A', 'TAIWAN', 'SAUDI ARABIA', 'JAPAN SM...   0.323264
# ['WORLD', 'CHINA A', 'TAIWAN', 'SAUDI ARABIA', ...   0.317245
# ['CHINA A', 'TAIWAN', 'SAUDI ARABIA', 'MEXICO',...   0.315798

# %% [markdown]
# #### Paragono minor volatilità con MSCI WORLD

# %%
which_string = results["vol"].idxmin()[1:-1].replace("'","")
which = which_string.split(", ")
which
# Out:
# ['WORLD', 'CHINA A', 'TAIWAN', 'SAUDI ARABIA', 'SOUTH AFRICA']

# %%
temp = dati2[which].dropna()
(100*temp/temp.iloc[0]).mean(axis=1).plot(figsize=(25,10),label=which_string)
(100*dati2["WORLD"].dropna()/dati2["WORLD"].dropna().iloc[0]).plot(figsize=(25,10))
plt.legend()

# %%
temp = dati2[which].dropna()
temp.pct_change(mesi,fill_method=None).mean(axis=1).dropna().plot(figsize=(25,10),label=which_string)
dati2["WORLD"].pct_change(mesi,fill_method=None).dropna().plot(figsize=(25,10))
plt.legend()

# %%
print(which_string)
display(temp.pct_change(mesi,fill_method=None).mean(axis=1).describe())
print("\nWORLD")
display(dati2["WORLD"].pct_change(mesi,fill_method=None).describe())
# Out:
# WORLD, CHINA A, TAIWAN, SAUDI ARABIA, SOUTH AFRICA
# count    64.000000
# mean      0.554031
# std       0.216755
# min      -0.029413
# 25%       0.444234
# 50%       0.546490
# 75%       0.744107
# max       0.889480
# dtype: float64
# WORLD
# count    228.000000
# mean       0.493501
# std        0.396006
# min       -0.243890
# 25%        0.052196
# 50%        0.601640
# 75%        0.822238
# max        1.285969
# Name: WORLD, dtype: float64

# %% [markdown]
# #### Paragono maggior Sharpetti con MSCI WORLD

# %%
which_string = results["Sharpetti"].idxmax()[1:-1].replace("'","")
which = which_string.split(", ")
which
# Out:
# ['WORLD', 'CHINA A', 'TAIWAN', 'SAUDI ARABIA', 'SOUTH AFRICA']

# %%
temp = dati2[which].dropna()
(100*temp/temp.iloc[0]).mean(axis=1).plot(figsize=(25,10),label=which_string)
(100*dati2["WORLD"].dropna()/dati2["WORLD"].dropna().iloc[0]).plot(figsize=(25,10))
plt.legend()

# %%
temp = dati2[which].dropna()
temp.pct_change(mesi,fill_method=None).mean(axis=1).dropna().plot(figsize=(25,10),label=which_string)
dati2["WORLD"].pct_change(mesi,fill_method=None).dropna().plot(figsize=(25,10))
plt.legend()

# %%
print(which_string)
display(temp.pct_change(mesi,fill_method=None).mean(axis=1).describe())
print("\nWORLD")
display(dati2["WORLD"].pct_change(mesi,fill_method=None).describe())
# Out:
# WORLD, CHINA A, TAIWAN, SAUDI ARABIA, SOUTH AFRICA
# count    64.000000
# mean      0.554031
# std       0.216755
# min      -0.029413
# 25%       0.444234
# 50%       0.546490
# 75%       0.744107
# max       0.889480
# dtype: float64
# WORLD
# count    228.000000
# mean       0.493501
# std        0.396006
# min       -0.243890
# 25%        0.052196
# 50%        0.601640
# 75%        0.822238
# max        1.285969
# Name: WORLD, dtype: float64

# %% [markdown]
# ## Algoritmo genetico (universitario)

# %%
len(dati2.columns)
# Out:
# 26

# %%
# creo i portafogli iniziali
portafogli = []
for i in range(0,len(dati2.columns),5):
    portafogli.append(dati2.columns[i:i+5])
if i < len(dati2.columns):
    # se l'ultimo è incompleto aggiungo
    for k in range(0,5 - (len(dati2.columns)-i)):
        portafogli[-1] = portafogli[-1].append(dati2.columns[k:k+1])
else:
    # altrimenti comunque aggiorno k perché magari lo uso dopo
    k = -1
if len(portafogli)%2 == 1:
    # se sono dispari ne creo un altro
    portafogli.append(dati2.columns[k+1:k+6])
portafogli
# Out:
# [Index(['WORLD', 'EM (EMERGING MARKETS) IMI', 'EUROPE', 'JAPAN IMI', 'INDIA'], dtype='object'),
#  Index(['WORLD SMALL CAP', 'CHINA', 'PACIFIC ex JAPAN', 'BRAZIL',
#         'EUROPE SMALL CAP'],
#        dtype='object'),
#  Index(['CHINA A', 'UNITED KINGDOM', 'NORDIC COUNTRIES', 'CANADA', 'TAIWAN'], dtype='object'),
#  Index(['SAUDI ARABIA', 'MEXICO', 'JAPAN SMALL CAP', 'SWITZERLAND',
#         'EM EASTERN EUROPE ex RUSSIA'],
#        dtype='object'),
#  Index(['KOREA', 'SINGAPORE', 'SOUTH AFRICA', 'GREECE', 'INDONESIA'], dtype='object'),
#  Index(['TURKEY', 'WORLD', 'EM (EMERGING MARKETS) IMI', 'EUROPE', 'JAPAN IMI'], dtype='object')]

# %%
# incrocio i portafogli, adesso che so che sono tutti completi e sono in numero pari
# for i in range(0,len(portafogli),2):

# %% [markdown]
# # Prendere i dati da JUSTETF

# %%
import json
import requests
import urllib.parse

# %%
# !pip install justetf-scraping[all]@git+https://github.com/druzsan/justetf-scraping.git
# Out:
# Collecting justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git (from justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Cloning https://github.com/druzsan/justetf-scraping.git to /tmp/pip-install-n7opivwf/justetf-scraping_fb33eadc6f5341929874af142a22d921
#   Running command git clone --filter=blob:none --quiet https://github.com/druzsan/justetf-scraping.git /tmp/pip-install-n7opivwf/justetf-scraping_fb33eadc6f5341929874af142a22d921
#   Resolved https://github.com/druzsan/justetf-scraping.git to commit 0ee042e56fae7d7e7f82749a438472ad26386abb
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2.2.2)
# Collecting pycountry<24.0.0,>=23.12.11 (from justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading pycountry-23.12.11-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2.32.3)
# Collecting notebook>=7.0.0 (from justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading notebook-7.3.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.13.2)
# Collecting jupyter-server<3,>=2.4.0 (from notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.4,>=4.3.6 (from notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading jupyterlab-4.3.6-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /usr/local/lib/python3.11/dist-packages (from notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (6.4.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2025.1.31)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (3.10.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (3.1.6)
# Collecting jupyter-client>=7.4.4 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (5.7.2)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (5.10.4)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (24.2)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.21.1)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (24.0.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (5.7.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (1.8.0)
# Collecting async-lru>=1.0.0 (from jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (6.17.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (75.1.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2.17.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (4.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (3.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (4.12.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.14.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (5.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.23.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (4.3.6)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (6.0.2)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2.18.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2.21.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.11/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.7.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (1.4.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (3.0.50)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (4.9.0)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (3.0.0)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.8.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git) (0.2.13)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->justetf-scraping@ git+https://github.com/druzsan/justetf-scraping.git->justetf-scraping[all]@ git+https://github.com/druzsan/justetf-scraping.git)
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Downloading notebook-7.3.3-py3-none-any.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 77.1 MB/s eta 0:00:00
# Downloading pycountry-23.12.11-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 75.1 MB/s eta 0:00:00
# Downloading jupyter_server-2.15.0-py3-none-any.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 kB 22.6 MB/s eta 0:00:00
# Downloading jupyterlab-4.3.6-py3-none-any.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 71.5 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 4.2 MB/s eta 0:00:00
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 8.6 MB/s eta 0:00:00
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 5.5 MB/s eta 0:00:00
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.3 MB/s eta 0:00:00
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.1 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Building wheels for collected packages: justetf-scraping
#   Building wheel for justetf-scraping (pyproject.toml) ... done
#   Created wheel for justetf-scraping: filename=justetf_scraping-0.1.0-py3-none-any.whl size=13625 sha256=6b1d7116040d93f427b52db6fc9d2a150bb22806049363261e96c55b48759323
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7bsoek04/wheels/f6/7a/2f/9f852679fbcd66f99c3618ab5ee372e31d9545e0bee9e106bc
# Successfully built justetf-scraping
# Installing collected packages: uri-template, types-python-dateutil, rfc3986-validator, rfc3339-validator, python-json-logger, pycountry, overrides, json5, jedi, fqdn, async-lru, jupyter-server-terminals, jupyter-client, arrow, justetf-scraping, isoduration, jupyter-events, jupyter-server, jupyterlab-server, jupyter-lsp, jupyterlab, notebook
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.16.0
#     Uninstalling jupyter-server-1.16.0:
#       Successfully uninstalled jupyter-server-1.16.0
#   Attempting uninstall: notebook
#     Found existing installation: notebook 6.5.7
#     Uninstalling notebook-6.5.7:
#       Successfully uninstalled notebook-6.5.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 7.3.3 which is incompatible.
# Successfully installed arrow-1.3.0 async-lru-2.0.5 fqdn-1.5.1 isoduration-20.11.0 jedi-0.19.2 json5-0.10.0 jupyter-client-8.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyterlab-4.3.6 jupyterlab-server-2.27.3 justetf-scraping-0.1.0 notebook-7.3.3 overrides-7.7.0 pycountry-23.12.11 python-json-logger-3.3.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 types-python-dateutil-2.9.0.20241206 uri-template-1.3.0

# %%
import justetf_scraping

# %%
etfs = justetf_scraping.load_overview()
etfs
# Out:
# /usr/local/lib/python3.11/dist-packages/justetf_scraping/overview.py:406: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[column] = df[column].replace({"Yes": True, "No": False}).astype("bool")
# /usr/local/lib/python3.11/dist-packages/justetf_scraping/overview.py:406: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[column] = df[column].replace({"Yes": True, "No": False}).astype("bool")
#                  wkn ticker     valor  \
# isin
# IE00B5BMR087  A0YEDG   SXR8  10737041
# IE00B4L5Y983  A0RPWH   EUNL  10608388
# IE00B3XXRP09  A1JX53   VUSA  18575508
# IE00B3YCGJ38  A1CYW7   P500  11358996
# IE00BKM4GZ66  A111X9   IS3N  24209517
# ...              ...    ...       ...
# XS2427363036  A3GWVS   2FLY      <NA>
# JE00B24DKJ77  A0V6Y0   4RTE      <NA>
# XS2842095759    <NA>   3SBB      <NA>
# XS2437455608  A3GXB6   STR2      <NA>
# XS2427474023  A3GWVN   O2IG      <NA>
#
#                                                            name  \
# isin
# IE00B5BMR087           iShares Core S&P 500 UCITS ETF USD (Acc)
# IE00B4L5Y983        iShares Core MSCI World UCITS ETF USD (Acc)
# IE00B3XXRP09      Vanguard S&P 500 UCITS ETF (USD) Distributing
# IE00B3YCGJ38                          Invesco S&P 500 UCITS ETF
# IE00BKM4GZ66  iShares Core MSCI Emerging Markets IMI UCITS E...
# ...                                                         ...
# XS2427363036  WisdomTree STOXX Europe Travel & Leisure 2x Da...
# JE00B24DKJ77                   WisdomTree Nickel 1x Daily Short
# XS2842095759           GraniteShares 3x Short Alibaba Daily ETP
# XS2437455608  WisdomTree STOXX Europe Travel & Leisure 2x Da...
# XS2427474023   WisdomTree STOXX Europe Oil & Gas 2x Daily Short
#
#              inception_date  age_in_days  age_in_years           strategy  \
# isin
# IE00B5BMR087     2010-05-19         5422     14.854795          Long-only
# IE00B4L5Y983     2009-09-25         5658     15.501370          Long-only
# IE00B3XXRP09     2012-05-22         4688     12.843836          Long-only
# IE00B3YCGJ38     2010-05-20         5421     14.852055          Long-only
# IE00BKM4GZ66     2014-05-30         3950     10.821918          Long-only
# ...                     ...          ...           ...                ...
# XS2427363036     2022-03-02         1117      3.060274  Short & Leveraged
# JE00B24DKJ77     2008-02-22         6239     17.093151  Short & Leveraged
# XS2842095759     2022-02-02         1145      3.136986  Short & Leveraged
# XS2437455608     2022-03-02         1117      3.060274  Short & Leveraged
# XS2427474023     2022-03-02         1117      3.060274  Short & Leveraged
#
#              domicile_country currency  ...  last_year_volatility  \
# isin                                    ...
# IE00B5BMR087          Ireland      USD  ...                 15.43
# IE00B4L5Y983          Ireland      USD  ...                 13.34
# IE00B3XXRP09          Ireland      USD  ...                 15.63
# IE00B3YCGJ38          Ireland      USD  ...                 15.45
# IE00BKM4GZ66          Ireland      USD  ...                 13.51
# ...                       ...      ...  ...                   ...
# XS2427363036          Ireland      EUR  ...                 33.31
# JE00B24DKJ77           Jersey      USD  ...                 25.36
# XS2842095759          Ireland      USD  ...                132.24
# XS2437455608          Ireland      EUR  ...                 33.19
# XS2427474023          Ireland      EUR  ...                 32.28
#
#               last_three_years_volatility last_five_years_volatility  \
# isin
# IE00B5BMR087                        17.83                      18.80
# IE00B4L5Y983                        15.05                      16.01
# IE00B3XXRP09                        18.04                      18.91
# IE00B3YCGJ38                        17.88                      18.85
# IE00BKM4GZ66                        13.46                      14.97
# ...                                   ...                        ...
# XS2427363036                        42.83                        NaN
# JE00B24DKJ77                        46.61                      49.42
# XS2842095759                       147.11                        NaN
# XS2437455608                        42.81                        NaN
# XS2427474023                        41.67                        NaN
#
#               last_year_return_per_risk last_three_years_return_per_risk  \
# isin
# IE00B5BMR087                       0.64                             0.58
# IE00B4L5Y983                       0.72                             0.63
# IE00B3XXRP09                       0.61                             0.56
# IE00B3YCGJ38                       0.62                             0.58
# IE00BKM4GZ66                       0.75                             0.29
# ...                                 ...                              ...
# XS2427363036                      -0.53                             0.08
# JE00B24DKJ77                       0.54                             0.54
# XS2842095759                      -0.72                            -0.56
# XS2437455608                       0.26                            -0.48
# XS2427474023                      -0.40                            -0.59
#
#               last_five_years_return_per_risk  max_drawdown  \
# isin
# IE00B5BMR087                             1.11        -33.71
# IE00B4L5Y983                             1.19        -33.91
# IE00B3XXRP09                             1.10        -33.70
# IE00B3YCGJ38                             1.12        -33.69
# IE00BKM4GZ66                             0.70        -34.34
# ...                                       ...           ...
# XS2427363036                              NaN        -42.03
# JE00B24DKJ77                            -0.54        -96.99
# XS2842095759                              NaN        -99.90
# XS2437455608                              NaN        -71.68
# XS2427474023                              NaN        -63.42
#
#               last_year_max_drawdown  last_three_years_max_drawdown  \
# isin
# IE00B5BMR087                  -13.35                         -15.92
# IE00B4L5Y983                  -11.29                         -15.01
# IE00B3XXRP09                  -13.35                         -16.10
# IE00B3YCGJ38                  -13.34                         -16.06
# IE00BKM4GZ66                  -10.36                         -17.53
# ...                              ...                            ...
# XS2427363036                  -36.10                         -41.91
# JE00B24DKJ77                  -23.84                         -47.83
# XS2842095759                  -96.62                         -99.72
# XS2437455608                  -42.95                         -71.27
# XS2427474023                  -25.16                         -58.53
#
#               last_five_years_max_drawdown
# isin
# IE00B5BMR087                        -17.11
# IE00B4L5Y983                        -16.88
# IE00B3XXRP09                        -17.28
# IE00B3YCGJ38                        -17.20
# IE00BKM4GZ66                        -23.61
# ...                                    ...
# XS2427363036                           NaN
# JE00B24DKJ77                        -89.44
# XS2842095759                           NaN
# XS2437455608                           NaN
# XS2427474023                           NaN
#
# [3503 rows x 42 columns]
